# %%
# !pip install transllm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting transllm
#   Downloading transllm-0.1.0-py3-none-any.whl (4.4 kB)
# Requirement already satisfied: requests in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (2.28.1)
# Requirement already satisfied: deep-translator in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (1.11.1)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from transllm) (0.4.6)
# Requirement already satisfied: httpx[http2] in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (0.13.3)
# Requirement already satisfied: torch in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (2.0.1+cu118)
# Collecting deepl (from transllm)
#   Using cached deepl-1.15.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: transformers in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (4.28.1)
# Requirement already satisfied: googletrans in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (3.1.0a0)
# Requirement already satisfied: bardapi in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transllm) (0.1.0)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in c:\programdata\anaconda3\lib\site-packages (from deep-translator->transllm) (4.11.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->transllm) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from requests->transllm) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from requests->transllm) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->transllm) (2021.10.8)
# Requirement already satisfied: hstspreload in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpx[http2]->transllm) (2023.1.1)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from httpx[http2]->transllm) (1.2.0)
# Requirement already satisfied: chardet==3.* in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpx[http2]->transllm) (3.0.4)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpx[http2]->transllm) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpx[http2]->transllm) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpcore==0.9.*->httpx[http2]->transllm) (0.9.0)
# Requirement already satisfied: h2==3.* in c:\users\parkm\appdata\roaming\python\python39\site-packages (from httpcore==0.9.*->httpx[http2]->transllm) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from h2==3.*->httpcore==0.9.*->httpx[http2]->transllm) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from h2==3.*->httpcore==0.9.*->httpx[http2]->transllm) (3.0.0)
# Requirement already satisfied: filelock in c:\users\parkm\appdata\roaming\python\python39\site-packages (from torch->transllm) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\programdata\anaconda3\lib\site-packages (from torch->transllm) (4.5.0)
# Requirement already satisfied: sympy in c:\programdata\anaconda3\lib\site-packages (from torch->transllm) (1.10.1)
# Requirement already satisfied: networkx in c:\programdata\anaconda3\lib\site-packages (from torch->transllm) (2.7.1)
# Requirement already satisfied: jinja2 in c:\programdata\anaconda3\lib\site-packages (from torch->transllm) (3.1.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transformers->transllm) (0.14.1)
# Requirement already satisfied: numpy>=1.17 in c:\programdata\anaconda3\lib\site-packages (from transformers->transllm) (1.24.2)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from transformers->transllm) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in c:\programdata\anaconda3\lib\site-packages (from transformers->transllm) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\programdata\anaconda3\lib\site-packages (from transformers->transllm) (2022.3.15)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from transformers->transllm) (0.13.2)
# Requirement already satisfied: tqdm>=4.27 in c:\programdata\anaconda3\lib\site-packages (from transformers->transllm) (4.64.0)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator->transllm) (2.3.1)
# Requirement already satisfied: fsspec in c:\programdata\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.11.0->transformers->transllm) (2022.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging>=20.0->transformers->transllm) (3.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\parkm\appdata\roaming\python\python39\site-packages (from jinja2->torch->transllm) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in c:\programdata\anaconda3\lib\site-packages (from sympy->torch->transllm) (1.2.1)
# Installing collected packages: deepl, transllm
# Successfully installed deepl-1.15.0 transllm-0.1.0
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\parkm\appdata\roaming\python\python39\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\parkm\appdata\roaming\python\python39\site-packages)
# WARNING: httpx 0.13.3 does not provide the extra 'http2'
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\parkm\appdata\roaming\python\python39\site-packages)
#   WARNING: The script deepl.exe is installed in 'C:\Users\parkm\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script transllm.exe is installed in 'C:\Users\parkm\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\parkm\appdata\roaming\python\python39\site-packages)

# %%
from transllm import LLMtranslator

model_path = 'openlm-research/open_llama_3b'
# model_path = 'openlm-research/open_llama_7b'
# model_path = 'openlm-research/open_llama_13b'


open_llama_kor = LLMtranslator(model_path, target_lang='ko', translator='google')


prompt = "안녕하세요, 오늘 날씨가 어떤가요?"
translation = open_llama_kor.generate(prompt)
print(translation)
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <cell line: 12>                                                                               │
# │                                                                                                  │
# │    9                                                                                             │
# │   10                                                                                             │
# │   11 prompt = "안녕하세요, 오늘 날씨가 어떤가요?"                                                │
# │ ❱ 12 translation = translator.generate(prompt)                                                   │
# │   13 print(translation)                                                                          │
# │   14                                                                                             │
# │                                                                                                  │
# │ C:\Users\parkm\AppData\Roaming\Python\Python39\site-packages\torch\utils\_contextlib.py:115 in   │
# │ decorate_context                                                                                 │
# │                                                                                                  │
# │   112 │   @functools.wraps(func)                                                                 │
# │   113 │   def decorate_context(*args, **kwargs):                                                 │
# │   114 │   │   with ctx_factory():                                                                │
# │ ❱ 115 │   │   │   return func(*args, **kwargs)                                                   │
# │   116 │                                                                                          │
# │   117 │   return decorate_context                                                                │
# │   118                                                                                            │
# │                                                                                                  │
# │ C:\Users\parkm\AppData\Roaming\Python\Python39\site-packages\transllm\core.py:120 in generate    │
# │                                                                                                  │
# │   117 │   │   │   str: The generated text in the target language.                                │
# │   118 │   │   """                                                                                │
# │   119 │   │   translated_prompt = self.translate_to_en(prompt)                                   │
# │ ❱ 120 │   │   input_ids = self.tokenizer(translated_prompt, return_tensors="pt").input_ids       │
# │   121 │   │   generation_output = self.model.generate(input_ids=input_ids, max_new_tokens=32)    │
# │   122 │   │   answer = self.tokenizer.decode(generation_output[0])                               │
# │   123 │   │   translated_answer = self.translate_to_targetlang(answer)                           │
# │                                                                                                  │
# │ C:\Users\parkm\AppData\Roaming\Python\Python39\site-packages\transformers\tokenization_utils_bas │
# │ e.py:2538 in __call__                                                                            │
# │                                                                                                  │
# │   2535 │   │   │   # input mode in this case.                                                    │
# │   2536 │   │   │   if not self._in_target_context_manager:                                       │
# │   2537 │   │   │   │   self._switch_to_input_mode()                                              │
# │ ❱ 2538 │   │   │   encodings = self._call_one(text=text, text_pair=text_pair, **all_kwargs)      │
# │   2539 │   │   if text_target is not None:                                                       │
# │   2540 │   │   │   self._switch_to_target_mode()                                                 │
# │   2541 │   │   │   target_encodings = self._call_one(text=text_target, text_pair=text_pair_targ  │
# │                                                                                                  │
# │ C:\Users\parkm\AppData\Roaming\Python\Python39\site-packages\transformers\tokenization_utils_bas │
# │ e.py:2596 in _call_one                                                                           │
# │                                                                                                  │
# │   2593 │   │   │   │   return False                                                              │
# │   2594 │   │                                                                                     │
# │   2595 │   │   if not _is_valid_text_input(text):                                                │
# │ ❱ 2596 │   │   │   raise ValueError(                                                             │
# │   2597 │   │   │   │   "text input must of type `str` (single example), `List[str]` (batch or s  │
# │   2598 │   │   │   │   "or `List[List[str]]` (batch of pretokenized examples)."                  │
# │   2599 │   │   │   )                                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: text input must of type `str` (single example), `List[str]` (batch or single pretokenized example) or
# `List[List[str]]` (batch of pretokenized examples).
